# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv("uni_data.csv")
df.drop(labels="Unnamed: 0", axis=1, inplace=True)

# %%
df_feature_columns = df.drop(
    labels=["Rank", "Institution", "Region", "Total Score"], axis=1
)
df_feature_columns
rows_with_all_features = Counter(df_feature_columns.count(axis=1))
rows_with_all_features
# Out:
# Counter({7: 145, 4: 1, 1: 434, 6: 4, 0: 6})

# %%
sns_palette = sns.color_palette("deep")

plt.pie(
    labels=["Dane dla wszystkich cech", "Brak danych dla niektórych cech"],
    x=[145, 445],
    autopct="%1.1f%%",
    colors=sns_palette,
)

plt.show()
